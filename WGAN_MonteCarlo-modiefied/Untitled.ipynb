# %%
import tensorflow as tf

# %%
tf.config.get_visible_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
# !conda list
# Out:
# # packages in environment at C:\Users\MiguelHoyo\miniconda3\envs\pytorch_v1_cuda_10_2:
# #
# # Name                    Version                   Build  Channel
# absl-py                   1.0.0                    pypi_0    pypi
# argon2-cffi               21.3.0             pyhd8ed1ab_0    conda-forge
# argon2-cffi-bindings      21.2.0          py310he2412df_1    conda-forge
# asttokens                 2.0.5              pyhd8ed1ab_0    conda-forge
# astunparse                1.6.3                    pypi_0    pypi
# attrs                     21.4.0             pyhd8ed1ab_0    conda-forge
# awkward                   1.8.0           py310h8a704f9_0    conda-forge
# awkward0                  0.15.5             pyhd8ed1ab_0    conda-forge
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# backports                 1.1                pyhd3eb1b0_0
# backports.functools_lru_cache 1.6.4              pyhd8ed1ab_0    conda-forge
# ...
